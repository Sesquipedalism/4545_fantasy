# %%
import pandas as pd
import numpy as np
import collections

# %%
num_boards = 10
price_csv_file_path = 'price_source_data.csv'
max_price = int(num_boards * 2000)

# %%
df = pd.read_csv(price_csv_file_path)
df = df[[col for col in df.columns if 'Price' in col or 'Board' in col]].copy()
df = df[~df.isnull().any(axis=1)]
df.columns = [item for sublist in [
    ['board_{}'.format(i), 'price_{}'.format(i)] for i in range(1, num_boards + 1)
    ] for item in sublist]
for col in [c for c in df if 'price' in c]:
    df[col] = df[col].str.slice(1).str.replace(",", ".").astype(float)
    df[col] = np.where(df[col] < num_boards*2, df[col]*1000, df[col]).astype(int)
df
# Out:
#               board_1  price_1           board_2  price_2  \
# 0            pepellou     2232     HampshireHawk     2580
# 1            DJ-Logan     1207            LeoYee     2344
# 2           Razorneck     2244     Zubenelgenubi     2261
# 3      Michael-Westen     2847    bufferunderrun     1593
# 4    Like-a-hurricane     4239              Kjar     2368
# 5          drchessdad     1354               mqj     1417
# 6         FlokiTheCat     1965             j3084     1347
# 7             rezoons     1595            y3LL3r     1534
# 8               Aidoz     2668            f1nn33     2213
# 9              jacade     2232     grabhispieces     1570
# 10    TRadjabaurusRex     1503             root2     2213
# 11         NathanielW     1377   QEDemonstrandum     2498
# 12        RexInvictus     1468              M0r1     2153
# 13         Ringelnatz     1331          Pauli314     1070
# 14         Pushedpawn     1434        roonster33     2403
# 15             Savvyd     2474     deathmetalled     1208
# 16         Shrekmated     2622         louiegunz     2045
# 17              Qudit     1218            VicPez     1950
# 18             okoros     3185         oleksiial     1771
# 19           milanrad     1320       atharsaleem     1760
# 20              eie24     1106         BloodyFox     2650
# 21             ginoux     1977        nerja25390     2213
# 22  FirstnameLastname     2451          Flubbing     1795
# 23         nuagesgris     2174             dave3     1700
# 24        wookash_888     3426       Radmankaruf     1487
# 25       SycoraxCirce     1641    ATrueRavenclaw     1546
# 26        tommeketoch     1838      Potatomancer     1440
# 27    Silkthewanderer     1309              Rcyx     1998
# 28           AlexGaul      486       x420noscope     2662
# 29             Pendru     1710    Sesquipedalism     2568
# 30              Skims     2348     Josue_Richard     2249
# 31           Groger12     1118       losttheplot     1358
# 32     Fearlessking64     4154          Artian12     2033
# 33             ErinYu     2724  mysonnevercallme     2650
# 34           Antisana     1118            Brundd     2638
# 35             Zerque     1537       mini_karpov     2118
# 36             ben622     1676           Knoddel     1903
# 37         chatakkuma     1297       texaspete09     1819
# 38           Fishmoro     1838         mronemore     2521
# 39       victormanolo     2814         timothyha     1452
# 40          CamLeslie     2497   osrswoodcutting     2627
# 41          IsaVulpes     2267            zschif     2296
#
#                  board_3  price_3            board_4  price_4  \
# 0             pulsar512b     1768         rsmillie94     1848
# 1                 AACtrl     1983         primeideal     2028
# 2                Karpyan     2342            N00b001     2268
# 3                  pioki     2294         kocimietka     2424
# 4             Paulze2000     1732         AbuShaitan     1860
# 5                 j123dh     2211              rodeo     2136
# 6              Seraya191     2103           weetbix2     1752
# 7                  Aphla      382              flaxl     2028
# 8                snorcal     1852    RunningInVienna      867
# 9              pie314271     2801           eigentor     2112
# 10             sexbucket     1971         ascoliloko     2136
# 11           Mackjalek97     1708             lopixl     1490
# 12               Ryzalis     1923            Whelp10     1692
# 13          pepehands321     2043       palet_master     1800
# 14              fgermuth     2461            ErunaMe     2172
# 15   KS_Legion_Legionowo     2354          RageEight     2076
# 16               far1108     2199        ButterPecan     1896
# 17          gavalanche20     1888              Seb32     2220
# 18           invinci7777     1852             Dtdeep     2328
# 19               esKaayY     1744       TalentedPoet     2028
# 20         phantom567459     2091             MPC455     2148
# 21             mixxanber     1852             NLance     1764
# 22        AlessandroGori     2055           ajajajaj     2016
# 23              itsphong     1756     DioBrando12345     1597
# 24     Chewbacca_Defense     2019         Lupo_Jones     2589
# 25       captaincomeback     1947              scvrf     2256
# 26              ngducphu     2271  ChewbakaTheRookie     1908
# 27           Schackmacke     1900            Forhavu     1692
# 28          KnightFury21     1912          Meeklydim     2040
# 29         Geigenzaehler     2127              fookh     1668
# 30           RedzoneNova     1804    FunkSoulBrother     1692
# 31                fhunfi     1732           Jamougha     2268
# 32                lion88     2318         flipiflapi     1896
# 33                  okei     1684            adande1     2148
# 34                 mgold     1518          WarGoblin     2172
# 35             benellis3     1601        BattleAxiom     2112
# 36         Bitter_Cherry     2271            alen111     2328
# 37          Grizzzly1000     2354          gmat20020     2483
# 38               pic1991     2055               sgis     2220
# 39          ChessPriyome     2223             scarff     2136
# 40  O1189998819991197253     2995            trex_47     1585
# 41                shetoo     1923         Rolfomania     2136
#
#                board_5  price_5              board_6  price_6  \
# 0        BobAnderson52     1977        SteveMcKinnon     2173
# 1          TheScythian     1264               ericBG     1860
# 2           kramopolis     1917       Wo_Cheng_Si_Le     2173
# 3              Roofies     3323             elTaljin     2448
# 4     amanlikekennyken     1737        iamtheknight2     2293
# 5              goirish     2085  TheGrandChessKnight     1824
# 6       plastic_pusher     1677              STCLion     2389
# 7              cowtone     1677               Gokuba     1812
# 8             Aaronmb2     1570             pinbsg21     1884
# 9               Narski     2025          Clarinetref     1968
# 10             Matt365     2301         failingtheIB     2161
# 11       ParkerInglett     2001          PaulWithAnS     1836
# 12          et5555yang     2205        wiktor-chomik     2543
# 13            Gogmatel     2169              Brainet     1836
# 14            thepaul1     1689               Rskyoz     2197
# 15  Andypandy123456789     2479              wernhao     1908
# 16          Cannonbait     1929           pepepibote     1716
# 17            Skackred     2001                  teg     1944
# 18     El_pollo_diablo     2384            Hindemith     1692
# 19    Wealth_And_Taste     2408             imikacic     2113
# 20              glbert     2085          Scaredpeach     1944
# 21           patalanoc     1773              RebelMe     1776
# 22            zADAcLaY     1809                Moccy     2052
# 23             JoseOMG     1701           csoamesy95     2508
# 24             mekumcu     1392             levier17     1788
# 25            Herzog51     1809          SouzaMoraes     1800
# 26          ColdTehran     1821          Daniel1802b     2389
# 27            wizzywop     2037         loungelizard     2101
# 28            Abolizer     2181               fwcj68     1752
# 29         aloo_bhaloo     2408             apdent42     2185
# 30          rampichino     1977         pedropablo72     1740
# 31          Davidc2214     2217               Jamoke     2113
# 32            nvasquez     1989            topspin15     2113
# 33              colwem     1893               jk1834     2065
# 34                dkol     1953              feskslo     1740
# 35      AlexMorgenthau     1965             wdhorton     1908
# 36             fvafier     2109         Midnightokar     1944
# 37              giziti     1617               Ecelal     2173
# 38                lc91     2025               aide23     1992
# 39             izzie26     2061           Rolihlahla     1335
# 40         plsletmewin     2253       charliehorse55     1920
# 41            cvillian     2133              aarp995     1920
#
#               board_7  price_7             board_8  price_8  \
# 0   ReheatedLeftovers     2011  cathode-ray-jepsen     2786
# 1            kamekura     1628           mahjoub98     2469
# 2           mfeeney88     2083                 ipr     1966
# 3               mrlam     2047            Archilas     1942
# 4            Jputterg     1999     secretarisvogel     2207
# 5             SlimanX     1783         bungalowboi     1750
# 6            vishAnan     1783         jameslatham     2338
# 7         housesounds     2203          psmathgeek     1894
# 8        marian_roman     1628              quaini     1417
# 9         flyhalf2k14     2023          Le-Penseur     2039
# 10    Zeebo_the_clown     2035   SrinivasBharathNK     1774
# 11        sephiroth87     2191          prajwal_nm     2290
# 12           Rivimies     1747       multiverse128     1954
# 13           zbidwell     1032              fzappa     1990
# 14             xandic     1783                 iqb     2063
# 15         samkellett     1843          ebisdikian     1990
# 16    TowerOfSolitude     1843       LouisBuckland     1300
# 17         egoncharik     2239       verboseamoeba     1870
# 18         Marcosocha     1879         frieslfrasl     2290
# 19           doughorn     1652            kostasvl     1906
# 20      cheerstochess     1783         SlowChess73     2039
# 21           piirimae     1903             GAdam31     1990
# 22         Thiagovisk     1771           Yakruna30     1607
# 23       Agood2inches     1939           masedog91     2183
# 24             erv123     2167          UncleVinny     2171
# 25              CornX     1747            Birdsell     1667
# 26           Tasunoro     1987              joehan     1703
# 27       Haspelknecht     2466             mojomoe     1894
# 28       Angrybird029     2251          Constant1n     2398
# 29       jackaardvark     2035       Highonpotnuse     2302
# 30   ishallwooopyoass     2299        LucaGaglia73     1894
# 31           Thooorin     1819            heidigjr     2623
# 32       JustChillJoe     2909         MomoSapiens     1774
# 33      osoplayschess     2513        Samuelsson22     2398
# 34         BrandrokID     2607               Hysth     2219
# 35              vejen     1462          Bebetter14     2087
# 36            twobits     2794             Lyrurus     2195
# 37      hazelchesster     1975          freddy267t     2123
# 38     alex-arsenault     2059             kotoole     1548
# 39               ssyx     1640            Halgilde     1512
# 40      lucasradaelli     2323           SedNomini     1359
# 41     Squire_Western     2131           Rylor3000     2099
#
#                board_9  price_9              board_10  price_10
# 0              KapuBen     1503          DamianDragon       767
# 1              Pifisch     2322               slam267      2614
# 2          vonSlattery     2766               Lexgrad       200
# 3         diegohdragon     2263             epabarker       322
# 4                ruhib     1363              Dawn4365       535
# 5          thiccclouds     2239                pat219      2291
# 6             jeremyjh     1965              Dingoe12      3821
# 7       AleksandrSudak     1727       matt_chess_play      2669
# 8        King_killer27     1989               tpk1024      2757
# 9               rhiehn     2286               Ezze_13       604
# 10             lagar83     2346      diecast_illusion      2952
# 11              snadyc     2156                Itroun       767
# 12       Barry_Forshaw     1574                Skift2      3392
# 13          eudaimoni4     2168             chiasmata      3196
# 14      restausverkauf     2179            dama_x_rey      2235
# 15             burni28     1374           mmorrisohio      1965
# 16            jurica_c     2025            greener255      2122
# 17             KaiM_03     1562         hoppycoldstar      3112
# 18      Stormerofbarns     1739               Marc999       881
# 19               mmgoo     2546               NickR98      3091
# 20           keithxm23     1444            UpGoerFive      2691
# 21              gorgol     1704          rafaelnajera      1976
# 22         Randomcello     1965              SirPunto      2257
# 23             Teo2491     1515          Crazywane254      2470
# 24                mqll     1562        wernervolkmann      1265
# 25            lepertoe     2709                Outbox      3027
# 26               mtkib     1527                 keeto      2636
# 27  BarbarAusBielefeld     2892               slvrdoc      1729
# 28     kamelstekspizza     1316              jsettle1      1774
# 29       LordPericulum     2310        electricfalcon      1232
# 30       ryanthelion98     1293               cinqued      2043
# 31  SaucySailorJackTar     2616            Eternal013      3269
# 32             Ross067     1609          Afoolishmind       200
# 33               Zher0     1739        tchristianclub      1243
# 34                ruip     2428  mumblecoredumbledore      2021
# 35        davegiltinan     2227        PocketKnight39      2713
# 36           texasadam     2049         Ferchosalgado      1942
# 37  gingersquirrelnuts     2084              larius88      2920
# 38     Ruslan_Shumilov     3161                   z0x      3102
# 39         Samuelglats     1087              caodanny      2746
# 40              badair     1609             fulmarsky      1167
# 41           jendrasek     3084                B2C4G7       200

# %%
class Player:
    def __init__(self, name, price, board):
        self.name = name
        self.price = price
        self.board = board

# %%
# Set up "graph"
d = {}
for board in range(1, num_boards + 1):
    d[board] = collections.defaultdict(list)
    board_col = 'board_{}'.format(board)
    price_col = 'price_{}'.format(board)
    for ix, row in df[[board_col, price_col]].iterrows():
        # Rules to simplify problem
        if board == 1 or board == 10:
            if row[price_col] < 2600:
                continue
        elif board == 2 or board == 9:
            if row[price_col] < 2200:
                continue
        elif board == 3 or board == 8:
            if row[price_col] < 2100:
                continue
        else:
            if row[price_col] > 2000:
                continue
        d[board][row[price_col]].append(Player(row[board_col], row[price_col], board))

# %%
# Solve the problem
solutions = []
memo = collections.defaultdict(list)

def dfs(current_solution, board, price):
    # End condition
    if len(current_solution) == num_boards:
        if price == max_price:
            solutions.append(current_solution)
            csum = 0
            for b in range(num_boards - 1):
                csum += current_solution[b]
                memo[(b + 1, csum)].append(current_solution[b + 1:])
            return True
        return False
    
    # Use memo when possible
    if (board, price) in memo:
        for suffix in memo[(board, price)]:
            solutions.append(current_solution + suffix)
        return bool(memo[(board, price)])
    
    # Normal search
    result = False
    for new_price in d[board + 1]:
        sum_price = price + new_price
        if sum_price <= max_price:
            result = dfs(current_solution+[new_price], board + 1, price + new_price) or result
    
    # If search was unsuccessful, remember that
    if not result:
        memo[(board, price)] = []

    return result

dfs([], 0, 0)
# Out:
# True

# %%
# Get number of unique solutions
csum = 0
for i, solution in enumerate(solutions):
    unique = 1
    for j, price in enumerate(solution):
        unique *= len(d[j+1][price])
    csum += unique
csum
# Out:
# 1222079

# %%
# Get random $20,000 team
random_team = np.random.randint(len(solutions))
print([(d[i + 1][price][0].name, d[i + 1][price][0].price/1000) 
       for i, price in enumerate(solutions[random_team])])
# Out:
# [('okoros', 3.185), ('Zubenelgenubi', 2.261), ('Seraya191', 2.103), ('RunningInVienna', 0.867), ('TheScythian', 1.264), ('Rolihlahla', 1.335), ('Rivimies', 1.747), ('Highonpotnuse', 2.302), ('Pifisch', 2.322), ('slam267', 2.614)]

# %%
# Get total number of possible teams
total = 1
for b in d:
    total *= len(d[b])
total
# Out:
# 392074862400
